# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1,2,3],[4,5,6]])
array2 = np.random.rand(3,3)
array3 = np.zeros((3,3))

# %%
print("array1",array1)
print("array2",array2)
print("array3",array3)
# Out:
# array1 [[1 2 3]
#  [4 5 6]]
# array2 [[0.67108333 0.46127824 0.4604908 ]
#  [0.16559099 0.58107742 0.75581763]
#  [0.18507947 0.41801269 0.83327767]]
# array3 [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
np.save("array1",array1)
np.save("array2",array2)
np.save("array3",array3)

# %%
try:
  logo = np.load("numpy-logo.npy")
  #display
  plt.figure(figsize=(10,5))
  plt.subplot(121)
  plt.imshow(logo)
  plt.title("numpy logo")
  plt.grid(False)
  plt.show()
  plt.subplot(122)
  dark_logo = 1 - logo
  plt.imshow(dark_logo)
  plt.title("numpy dark logo")
  plt.grid(False)
  plt.show()
except:
  print("file not found")

# %%
import numpy as np
v = np.array([[10, 20, 30, 40],[5,6,7,8]])
print(v.shape)
# Out:
# (2, 4)

# %%
print(v)
# Out:
# [[10 20 30 40]
#  [ 5  6  7  8]]
